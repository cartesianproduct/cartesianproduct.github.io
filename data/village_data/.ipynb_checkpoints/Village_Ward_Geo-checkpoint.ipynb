# %% [markdown]
# # Table of Contents
# * [Master Merge](#Master-Merge)

# %% [markdown]
# # Introduction
#
# Data and Code by Victor Garcia and Zachary Thomas.
#
# You can directly pull the `Myanmar PCodes Release-VIII_Aug2015 (StRgn_Dist_Tsp_Town_Ward_VT)` file from this [link](http://www.themimu.info/sites/themimu.info/files/documents/Myanmar_PCodes_Release-VIII_Aug2015_StRgn_Dist_Tsp_Town_Ward_VT.rar) which can be found on [this webpage](http://www.themimu.info/states_regions/country-wide) underneath the "Useful Resources" tab. It can also be found on this [page](http://www.themimu.info/place-codes) underneath "P Code Datasets", on pg 2. at the bottom.
#
# More generally, there are some awesome datasets here, I would say.
#
# This code produces `VT_Ward_geo.csv`, which was ultimately used in our final product.
#
# It also produces `VT_geo.csv` and `wards_geo.csv` -- I shared these with Victor but am unsure what purpose they served. (Probably to share P-codes).
#
# Victor gave me `outcsv.tar.gz`, which is data he pulled from an excel file. Not sure where that file came from though!

# %%
import os

# %% [markdown]
# # Read in Data

# %%
towns_df = pd.read_excel('Myanmar PCodes Release-VIII_Aug2015 (StRgn_Dist_Tsp_Town_Ward_VT).xlsx', sheetname='Towns')
wards_df = pd.read_excel('Myanmar PCodes Release-VIII_Aug2015 (StRgn_Dist_Tsp_Town_Ward_VT).xlsx', sheetname='Wards')

# %%
VT_df = pd.read_excel('Myanmar PCodes Release-VIII_Aug2015 (StRgn_Dist_Tsp_Town_Ward_VT).xlsx', sheetname='Village Tracts')

# %%
villages_df = pd.read_excel('Myanmar PCodes Release-VIII_Aug2015 (Villages).xlsx', sheetname=0)

# %%
wards_df.columns
# Out:
# Index(['SR_Pcode', 'State_Region', 'D_Pcode', 'District', 'TS_Pcode',
#        'Township', 'Town_Pcode', 'Town', 'Ward_Pcode', 'Ward', 'Ward_Mya_MM3',
#        'Source', 'Remark'],
#       dtype='object')

# %% [markdown]
# # Data Merging

# %% [markdown]
# Join towns_df and wards_df on `Town_Pcode`

# %%
wards_geo_df2= pd.merge(towns_df[['Township', 'District','Town_Pcode','Longitude','Latitude']], wards_df[['Town_Pcode', 'Ward_Pcode', 'Ward']], on = 'Town_Pcode')

# %%
wards_geo_df2
# Out:
#               Township    District    Town_Pcode  Longitude   Latitude  \
# 0            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 1            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 2            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 3            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 4            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 5            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 6            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 7            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 8            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 9            Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 10           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 11           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 12           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 13           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 14           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 15           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 16           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 17           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 18           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 19           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 20           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 21           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 22           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 23           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 24           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 25           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 26           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 27           Myitkyina   Myitkyina  MMR001001701  97.390355  25.387488
# 28           Myitkyina   Myitkyina  MMR001001702  97.039169  24.779234
# 29           Myitkyina   Myitkyina  MMR001001702  97.039169  24.779234
# ...                ...         ...           ...        ...        ...
# 3140    Poke Ba Thi Ri   Oke Ta Ra  MMR018005701  96.183000  19.806000
# 3141    Poke Ba Thi Ri   Oke Ta Ra  MMR018005701  96.183000  19.806000
# 3142    Poke Ba Thi Ri   Oke Ta Ra  MMR018005701  96.183000  19.806000
# 3143    Poke Ba Thi Ri   Oke Ta Ra  MMR018005701  96.183000  19.806000
# 3144    Poke Ba Thi Ri   Oke Ta Ra  MMR018005701  96.183000  19.806000
# 22    MMR001001701523                   Kyet Paung Chan Ward
# 23    MMR001001701524                      Myo Thit Gyi Ward
# 24    MMR001001701525                          Lel Kone Ward
# 25    MMR001001701526                          Shwe Aik Ward
# 26    MMR001001701527                     Shwe Pyi Thar Ward
# 27    MMR001001701528                         Pan Ma Ti Ward
# 28    MMR001001702501                         Aye Yar U Ward
# 29    MMR001001702502                   Aung Min Ga Lar Ward
# ...               ...                                    ...
# 3140  MMR018005701504                       Wunna Di Pa Ward
# 3141  MMR018005701505                     Thu Kha Di Pa Ward
# 3142  MMR018005701506                    Za Wa Na Di Pa Ward
# 3143  MMR018005701507                   Ya Da Nar Di Pa Ward
# 3144  MMR018005701508                     Zay Yar Di Pa Ward
# 3145  MMR018005701509                    Shin Phyu Shin Ward
# 3146  MMR018005701510                         Na Wa Day Ward
# 3147  MMR018005701511                  Ta Pin Shwe Htee Ward
# 3148  MMR018005701512   Kyi Taung Kan No. (1) Ward(Myo Thit)
# 3149  MMR018005701513      Kyi Taung Kan No. (2) Ward(Myoma)
# 3150  MMR018005701514   Kyi Taung Kan No. (3) Ward(Myohaung)
# 3151  MMR018005701515    Kyi Taung Kan No. (4) Ward(Kan Nar)
# 3152  MMR018005701516  Kyi Taung Kan No. (5) Ward(Sone Kone)
# 3153  MMR018005701517  Kyi Taung Kan No. (6) Ward(Thae Kyin)
# 3154  MMR018006701501                         Ywar Kauk Ward
# 3155  MMR018006701502                      Yan Aung (1) Ward
# 3156  MMR018006701503                      Yan Aung (2) Ward
# 3157  MMR018006701504                          Shwe Chi Ward
# 3158  MMR018006701505                        Min Ga Lar Ward
# 3159  MMR018006701506                      Baw Ga Wa Di Ward
# 3160  MMR018006701507                          U Yin Su Ward
# 3161  MMR018007701501                            No (1) Ward
# 3162  MMR018007701502                            No (2) Ward
# 3163  MMR018007701503                            No (3) Ward
# 3164  MMR018007701504                            No (4) Ward
# 3165  MMR018007701505                            No (5) Ward
# 3166  MMR018007701506                            No (6) Ward
# 3167  MMR018007701507                            No (7) Ward
# 3168  MMR018008701501                  Oke Ta Ra Thi Ri Ward
# 3169  MMR018008701502                    Shwe Nant Thar Ward
#
# [3170 rows x 7 columns]

# %%
wards_geo_df.to_csv('wards_geo.csv')

# %% [markdown]
# Group by Village Tract, get average Lat and Long

# %%
villages_df.columns
# Out:
# Index(['SR_Pcode', 'State_Region', 'D_Pcode', 'District', 'TS_Pcode',
#        'Township', 'VT_Pcode', 'Village_Tract', 'Village_Pcode', 'Village',
#        'Village_Mya_MMR3', 'Alternate_Vlg_name_Eng', 'Alternate_Vll_Name_Mya',
#        'Longitude', 'Latitude', 'Source', 'Remark', 'Remark_2'],
#       dtype='object')

# %%
village_geo3 = villages_df.groupby(['VT_Pcode', 'Village_Tract', 'District', 'Township'])['Longitude', 'Latitude'].mean()

# %%
village_geo3
# Out:
#                                                                 Longitude  \
# VT_Pcode     Village_Tract         District   Township
# MMR001001001 Alam                  Myitkyina  Myitkyina         97.494898
# MMR001001002 Nawng Nang            Myitkyina  Myitkyina         97.454205
# MMR001001003 Pa La Na Sa Khan Myar Myitkyina  Myitkyina         97.403838
# MMR001001029 Waing Lon             Myitkyina  Myitkyina               NaN
# MMR001001030 Tar Hoe Nar           Myitkyina  Myitkyina         24.890430
# ...                                                                   ...
# MMR018007039 Thit Poke Pin         Det Khi Na Lewe              19.577520
# MMR018007040 Min Pyin              Det Khi Na Lewe              19.603286
# MMR018007041 Ya Bein               Det Khi Na Lewe              19.539238
# MMR018007042 Aung Thar             Det Khi Na Lewe              19.482870
# MMR018007043 Tha Yet Chaung        Det Khi Na Lewe              19.718830
# MMR018007044 Thaw Hmaw Kone        Det Khi Na Lewe              19.636393
# MMR018007045 Thit Kyein            Det Khi Na Lewe              19.492578
# MMR018007046 Thea Kaw Gyi          Det Khi Na Lewe              19.629683
# MMR018007047 Thit Seint Pin        Det Khi Na Lewe              19.649227
# MMR018007048 Thet Kei Chin         Det Khi Na Lewe              19.662140
# MMR018007049 Tha Pyay Kone         Det Khi Na Lewe              19.543713
# MMR018007050 Thar Wut Hti          Det Khi Na Lewe              19.537524
# MMR018007051 Pauk Myaing           Det Khi Na Lewe              19.521123
# MMR018007052 Tha Yet Kone          Det Khi Na Lewe              19.499945
# MMR018007053 In Pin                Det Khi Na Lewe              19.498932
# MMR018007054 Aung Kone             Det Khi Na Lewe              19.655199
# MMR018007055 Aye Lar               Det Khi Na Lewe              19.611290
# MMR018007056 Ah Lel Kyun           Det Khi Na Lewe              19.542396
# MMR018007057 Aye Chan Thar         Det Khi Na Lewe              19.600330
# MMR018007058 Zali Hnget Gyi Taung  Det Khi Na Lewe              19.529948
# MMR018007059 Oke Shit Hlaing       Det Khi Na Lewe              19.729903
# MMR018007060 Shwe Pyi Thar         Det Khi Na Lewe                    NaN
# MMR018008001 Za Laung              Oke Ta Ra  Oke Ta Ra Thi Ri  19.800077
# MMR018008002 Taung Nyo             Oke Ta Ra  Oke Ta Ra Thi Ri  19.916686
# MMR018008003 Moe Swe               Oke Ta Ra  Oke Ta Ra Thi Ri  19.928265
# MMR018008004 Maung Yan             Oke Ta Ra  Oke Ta Ra Thi Ri  19.820570
# MMR018008005 Min Kone              Oke Ta Ra  Oke Ta Ra Thi Ri  19.842586
# MMR018008006 Tat Shaine            Oke Ta Ra  Oke Ta Ra Thi Ri  20.030580
# MMR018008007 Tha Yet Taw           Oke Ta Ra  Oke Ta Ra Thi Ri  19.980420
# MMR018008008 Hpa Yar Taung         Oke Ta Ra  Oke Ta Ra Thi Ri  20.032660
#
# [13974 rows x 2 columns]

# %%
village_geo.to_csv('VT_geo.csv')

# %% [markdown]
# `outcsv.tar.gz` came from Victor. He found an excel with previously unseen village data, and managed to munge out the data. He then put it into a zip file and sent it to me for data joining. I stored this data in `VT_ward_df`.

# %%
# !tar -xzvf outcsv.tar.gz
# Out:
# x OUTCSV/
# x OUTCSV/0_ward_villagepop.csv
# x OUTCSV/100_ward_villagepop.csv
# x OUTCSV/101_ward_villagepop.csv
# x OUTCSV/102_ward_villagepop.csv
# x OUTCSV/103_ward_villagepop.csv
# x OUTCSV/104_ward_villagepop.csv
# x OUTCSV/105_ward_villagepop.csv
# x OUTCSV/106_ward_villagepop.csv
# x OUTCSV/56_ward_villagepop.csv
# x OUTCSV/57_ward_villagepop.csv
# x OUTCSV/58_ward_villagepop.csv
# x OUTCSV/59_ward_villagepop.csv
# x OUTCSV/5_ward_villagepop.csv
# x OUTCSV/60_ward_villagepop.csv
# x OUTCSV/61_ward_villagepop.csv
# x OUTCSV/62_ward_villagepop.csv
# x OUTCSV/63_ward_villagepop.csv
# x OUTCSV/64_ward_villagepop.csv
# x OUTCSV/65_ward_villagepop.csv
# x OUTCSV/66_ward_villagepop.csv
# x OUTCSV/67_ward_villagepop.csv
# x OUTCSV/68_ward_villagepop.csv
# x OUTCSV/69_ward_villagepop.csv
# x OUTCSV/6_ward_villagepop.csv
# x OUTCSV/70_ward_villagepop.csv
# x OUTCSV/71_ward_villagepop.csv
# x OUTCSV/72_ward_villagepop.csv
# x OUTCSV/73_ward_villagepop.csv
# x OUTCSV/74_ward_villagepop.csv
# x OUTCSV/75_ward_villagepop.csv
# x OUTCSV/76_ward_villagepop.csv
# x OUTCSV/77_ward_villagepop.csv
# x OUTCSV/78_ward_villagepop.csv
# x OUTCSV/79_ward_villagepop.csv
# x OUTCSV/7_ward_villagepop.csv
# x OUTCSV/80_ward_villagepop.csv
# x OUTCSV/81_ward_villagepop.csv
# x OUTCSV/82_ward_villagepop.csv
# x OUTCSV/83_ward_villagepop.csv
# x OUTCSV/84_ward_villagepop.csv
# x OUTCSV/85_ward_villagepop.csv
# x OUTCSV/86_ward_villagepop.csv
# x OUTCSV/87_ward_villagepop.csv
# x OUTCSV/88_ward_villagepop.csv
# x OUTCSV/89_ward_villagepop.csv
# x OUTCSV/8_ward_villagepop.csv
# x OUTCSV/90_ward_villagepop.csv
# x OUTCSV/91_ward_villagepop.csv
# x OUTCSV/92_ward_villagepop.csv
# x OUTCSV/93_ward_villagepop.csv
# x OUTCSV/94_ward_villagepop.csv
# x OUTCSV/95_ward_villagepop.csv
# x OUTCSV/96_ward_villagepop.csv
# x OUTCSV/97_ward_villagepop.csv
# x OUTCSV/98_ward_villagepop.csv
# x OUTCSV/99_ward_villagepop.csv
# x OUTCSV/9_ward_villagepop.csv

# %%
os.listdir('OUTCSV')
# Out:
# ['0_ward_villagepop.csv',
#  '100_ward_villagepop.csv',
#  '101_ward_villagepop.csv',
#  '102_ward_villagepop.csv',
#  '103_ward_villagepop.csv',
#  '104_ward_villagepop.csv',
#  '105_ward_villagepop.csv',
#  '106_ward_villagepop.csv',
#  '107_ward_villagepop.csv',
#  '108_ward_villagepop.csv',
#  '109_ward_villagepop.csv',
#  '10_ward_villagepop.csv',
#  '110_ward_villagepop.csv',
#  '111_ward_villagepop.csv',
#  '112_ward_villagepop.csv',
#  '113_ward_villagepop.csv',
#  '114_ward_villagepop.csv',
#  '115_ward_villagepop.csv',
#  '116_ward_villagepop.csv',
#  '117_ward_villagepop.csv',
#  '118_ward_villagepop.csv',
#  '119_ward_villagepop.csv',
#  '11_ward_villagepop.csv',
#  '120_ward_villagepop.csv',
#  '121_ward_villagepop.csv',
#  '122_ward_villagepop.csv',
#  '123_ward_villagepop.csv',
#  '124_ward_villagepop.csv',
#  '125_ward_villagepop.csv',
#  '126_ward_villagepop.csv',
#  '127_ward_villagepop.csv',
#  '128_ward_villagepop.csv',
#  '129_ward_villagepop.csv',
#  '12_ward_villagepop.csv',
#  '130_ward_villagepop.csv',
#  '131_ward_villagepop.csv',
#  '132_ward_villagepop.csv',
#  '133_ward_villagepop.csv',
#  '134_ward_villagepop.csv',
#  '135_ward_villagepop.csv',
#  '136_ward_villagepop.csv',
#  '137_ward_villagepop.csv',
#  '138_ward_villagepop.csv',
#  '139_ward_villagepop.csv',
#  '13_ward_villagepop.csv',
#  '140_ward_villagepop.csv',
#  '141_ward_villagepop.csv',
#  '142_ward_villagepop.csv',
#  '143_ward_villagepop.csv',
#  '144_ward_villagepop.csv',
#  '145_ward_villagepop.csv',
#  '146_ward_villagepop.csv',
#  '147_ward_villagepop.csv',
#  '148_ward_villagepop.csv',
#  '149_ward_villagepop.csv',
#  '14_ward_villagepop.csv',
#  '150_ward_villagepop.csv',
#  '151_ward_villagepop.csv',
#  '152_ward_villagepop.csv',
#  '153_ward_villagepop.csv',
#  '154_ward_villagepop.csv',
#  '155_ward_villagepop.csv',
#  '156_ward_villagepop.csv',
#  '157_ward_villagepop.csv',
#  '158_ward_villagepop.csv',
#  '159_ward_villagepop.csv',
#  '15_ward_villagepop.csv',
#  '160_ward_villagepop.csv',
#  '161_ward_villagepop.csv',
#  '162_ward_villagepop.csv',
#  '163_ward_villagepop.csv',
#  '164_ward_villagepop.csv',
#  '165_ward_villagepop.csv',
#  '166_ward_villagepop.csv',
#  '167_ward_villagepop.csv',
#  '168_ward_villagepop.csv',
#  '169_ward_villagepop.csv',
#  '16_ward_villagepop.csv',
#  '170_ward_villagepop.csv',
#  '171_ward_villagepop.csv',
#  '172_ward_villagepop.csv',
#  '173_ward_villagepop.csv',
#  '174_ward_villagepop.csv',
#  '175_ward_villagepop.csv',
#  '176_ward_villagepop.csv',
#  '177_ward_villagepop.csv',
#  '178_ward_villagepop.csv',
#  '179_ward_villagepop.csv',
#  '17_ward_villagepop.csv',
#  '180_ward_villagepop.csv',
#  '181_ward_villagepop.csv',
#  '182_ward_villagepop.csv',
#  '183_ward_villagepop.csv',
#  '184_ward_villagepop.csv',
#  '185_ward_villagepop.csv',
#  '186_ward_villagepop.csv',
#  '187_ward_villagepop.csv',
#  '188_ward_villagepop.csv',
#  '189_ward_villagepop.csv',
#  '18_ward_villagepop.csv',
#  '190_ward_villagepop.csv',
#  '191_ward_villagepop.csv',
#  '192_ward_villagepop.csv',
#  '193_ward_villagepop.csv',
#  '194_ward_villagepop.csv',
#  '195_ward_villagepop.csv',
#  '196_ward_villagepop.csv',
#  '197_ward_villagepop.csv',
#  '198_ward_villagepop.csv',
#  '199_ward_villagepop.csv',
#  '19_ward_villagepop.csv',
#  '1_ward_villagepop.csv',
#  '200_ward_villagepop.csv',
#  '201_ward_villagepop.csv',
#  '202_ward_villagepop.csv',
#  '203_ward_villagepop.csv',
#  '204_ward_villagepop.csv',
#  '205_ward_villagepop.csv',
#  '206_ward_villagepop.csv',
#  '207_ward_villagepop.csv',
#  '208_ward_villagepop.csv',
#  '209_ward_villagepop.csv',
#  '20_ward_villagepop.csv',
#  '210_ward_villagepop.csv',
#  '211_ward_villagepop.csv',
#  '212_ward_villagepop.csv',
#  '213_ward_villagepop.csv',
#  '214_ward_villagepop.csv',
#  '215_ward_villagepop.csv',
#  '216_ward_villagepop.csv',
#  '217_ward_villagepop.csv',
#  '218_ward_villagepop.csv',
#  '219_ward_villagepop.csv',
#  '21_ward_villagepop.csv',
#  '220_ward_villagepop.csv',
#  '221_ward_villagepop.csv',
#  '222_ward_villagepop.csv',
#  '223_ward_villagepop.csv',
#  '224_ward_villagepop.csv',
#  '225_ward_villagepop.csv',
#  '226_ward_villagepop.csv',
#  '227_ward_villagepop.csv',
#  '228_ward_villagepop.csv',
#  '229_ward_villagepop.csv',
#  '22_ward_villagepop.csv',
#  '230_ward_villagepop.csv',
#  '231_ward_villagepop.csv',
#  '232_ward_villagepop.csv',
#  '233_ward_villagepop.csv',
#  '234_ward_villagepop.csv',
#  '235_ward_villagepop.csv',
#  '236_ward_villagepop.csv',
#  '237_ward_villagepop.csv',
#  '238_ward_villagepop.csv',
#  '239_ward_villagepop.csv',
#  '23_ward_villagepop.csv',
#  '240_ward_villagepop.csv',
#  '241_ward_villagepop.csv',
#  '242_ward_villagepop.csv',
#  '243_ward_villagepop.csv',
#  '244_ward_villagepop.csv',
#  '245_ward_villagepop.csv',
#  '246_ward_villagepop.csv',
#  '247_ward_villagepop.csv',
#  '248_ward_villagepop.csv',
#  '249_ward_villagepop.csv',
#  '24_ward_villagepop.csv',
#  '250_ward_villagepop.csv',
#  '251_ward_villagepop.csv',
#  '252_ward_villagepop.csv',
#  '253_ward_villagepop.csv',
#  '254_ward_villagepop.csv',
#  '255_ward_villagepop.csv',
#  '256_ward_villagepop.csv',
#  '257_ward_villagepop.csv',
#  '258_ward_villagepop.csv',
#  '259_ward_villagepop.csv',
#  '25_ward_villagepop.csv',
#  '260_ward_villagepop.csv',
#  '261_ward_villagepop.csv',
#  '262_ward_villagepop.csv',
#  '263_ward_villagepop.csv',
#  '264_ward_villagepop.csv',
#  '265_ward_villagepop.csv',
#  '266_ward_villagepop.csv',
#  '267_ward_villagepop.csv',
#  '268_ward_villagepop.csv',
#  '269_ward_villagepop.csv',
#  '26_ward_villagepop.csv',
#  '270_ward_villagepop.csv',
#  '271_ward_villagepop.csv',
#  '272_ward_villagepop.csv',
#  '27_ward_villagepop.csv',
#  '28_ward_villagepop.csv',
#  '29_ward_villagepop.csv',
#  '2_ward_villagepop.csv',
#  '30_ward_villagepop.csv',
#  '31_ward_villagepop.csv',
#  '32_ward_villagepop.csv',
#  '33_ward_villagepop.csv',
#  '34_ward_villagepop.csv',
#  '35_ward_villagepop.csv',
#  '36_ward_villagepop.csv',
#  '37_ward_villagepop.csv',
#  '38_ward_villagepop.csv',
#  '39_ward_villagepop.csv',
#  '3_ward_villagepop.csv',
#  '40_ward_villagepop.csv',
#  '41_ward_villagepop.csv',
#  '42_ward_villagepop.csv',
#  '43_ward_villagepop.csv',
#  '44_ward_villagepop.csv',
#  '45_ward_villagepop.csv',
#  '46_ward_villagepop.csv',
#  '47_ward_villagepop.csv',
#  '48_ward_villagepop.csv',
#  '49_ward_villagepop.csv',
#  '4_ward_villagepop.csv',
#  '50_ward_villagepop.csv',
#  '51_ward_villagepop.csv',
#  '52_ward_villagepop.csv',
#  '53_ward_villagepop.csv',
#  '54_ward_villagepop.csv',
#  '55_ward_villagepop.csv',
#  '56_ward_villagepop.csv',
#  '57_ward_villagepop.csv',
#  '58_ward_villagepop.csv',
#  '59_ward_villagepop.csv',
#  '5_ward_villagepop.csv',
#  '60_ward_villagepop.csv',
#  '61_ward_villagepop.csv',
#  '62_ward_villagepop.csv',
#  '63_ward_villagepop.csv',
#  '64_ward_villagepop.csv',
#  '65_ward_villagepop.csv',
#  '66_ward_villagepop.csv',
#  '67_ward_villagepop.csv',
#  '68_ward_villagepop.csv',
#  '69_ward_villagepop.csv',
#  '6_ward_villagepop.csv',
#  '70_ward_villagepop.csv',
#  '71_ward_villagepop.csv',
#  '72_ward_villagepop.csv',
#  '73_ward_villagepop.csv',
#  '74_ward_villagepop.csv',
#  '75_ward_villagepop.csv',
#  '76_ward_villagepop.csv',
#  '77_ward_villagepop.csv',
#  '78_ward_villagepop.csv',
#  '79_ward_villagepop.csv',
#  '7_ward_villagepop.csv',
#  '80_ward_villagepop.csv',
#  '81_ward_villagepop.csv',
#  '82_ward_villagepop.csv',
#  '83_ward_villagepop.csv',
#  '84_ward_villagepop.csv',
#  '85_ward_villagepop.csv',
#  '86_ward_villagepop.csv',
#  '87_ward_villagepop.csv',
#  '88_ward_villagepop.csv',
#  '89_ward_villagepop.csv',
#  '8_ward_villagepop.csv',
#  '90_ward_villagepop.csv',
#  '91_ward_villagepop.csv',
#  '92_ward_villagepop.csv',
#  '93_ward_villagepop.csv',
#  '94_ward_villagepop.csv',
#  '95_ward_villagepop.csv',
#  '96_ward_villagepop.csv',
#  '97_ward_villagepop.csv',
#  '98_ward_villagepop.csv',
#  '99_ward_villagepop.csv',
#  '9_ward_villagepop.csv']

# %%
filenames = os.listdir('OUTCSV')

# %%
VT_ward_df = pd.read_csv('OUTCSV/'+filenames[0])

# %%
VT_ward_df 
for filename in filenames[1:]:
    VT_ward_df = pd.concat([VT_ward_df, pd.read_csv('OUTCSV/'+filename)])

# %%
VT_ward_df.head(30)
# Out:
#                  Ward/VillageTract  tot_pop  male_pop  female_pop  \
# 0                       Aye Yar(W)   3647.0    1694.0      1953.0
# 1                       Thi Dar(W)   4143.0    2094.0      2049.0
# 2                  Yan Gyi Aung(W)   5309.0    2430.0      2879.0
# 3                  Du Ka Htaung(W)   8888.0    3845.0      5043.0
# 4                        Myo Ma(W)   1369.0     657.0       712.0
# 5                       Min Yat(W)    931.0     421.0       510.0
# 6               Shan Su (North)(W)   1418.0     674.0       744.0
# 7               Shan Su (South)(W)   1366.0     664.0       702.0
# 8                     Kachin Su(W)   2267.0    1024.0      1243.0
# 9                 Kyun Pin Thar(W)   6106.0    2786.0      3320.0
# 10                  Aye Zay Di (W)   5004.0    2321.0      2683.0
# 11              Shwe Nyaung Pin(W)   9491.0    4277.0      5214.0
# 12                    Myo Thit (W)   2067.0     990.0      1077.0
# 1  Myitkyina  Myitkyina  MMR001001701  97.390355  25.387488  MMR001001701502
# 2  Myitkyina  Myitkyina  MMR001001701  97.390355  25.387488  MMR001001701503
# 3  Myitkyina  Myitkyina  MMR001001701  97.390355  25.387488  MMR001001701504
# 4  Myitkyina  Myitkyina  MMR001001701  97.390355  25.387488  MMR001001701505
#
#                 Ward
# 0       Aye Yar Ward
# 1       Thi Dar Ward
# 2  Yan Gyi Aung Ward
# 3  Du Ka Htaung Ward
# 4        Myo Ma Ward

# %%
def text_edit(df, ward = True):
    '''
    INPUT: Dataframe
    OUTPUT: Dataframe with columns in correct text format for merging 
    '''
    df['Township'] =  df['Township'] + " Township"
    df['District'] = df['District'] + " District"
    if ward:
        def warder(name):
            name = name.split(' ')[:-1]
            return ' '.join(name) + "(W)"
        df['Ward'] = df['Ward'].apply(warder)
    else:
        df['Village_Tract'] = df['Village_Tract'] + "(VT)"
    return df

# %%
village_geo3 = village_geo3.reset_index()

# %%
wards_geo_df2 = text_edit(wards_geo_df2, ward = True)
village_geo3 = text_edit(village_geo3, ward = False)

# %%
VT_ward_df['Ward/VillageTract'] = VT_ward_df['Ward/VillageTract'].str.replace(" ", "")

# %%
VT_ward_df['district'] = VT_ward_df['district'].str.replace(" ", "")

# %%
village_geo3.columns
# Out:
# Index(['VT_Pcode', 'Village_Tract', 'District', 'Township', 'Longitude',
#        'Latitude'],
#       dtype='object')

# %%
wards_geo_df2['Ward'] = wards_geo_df2.Ward.str.replace(" ", "")

# %%
wards_geo_df2['District'] = wards_geo_df2.District.str.replace(" ", "")

# %%
village_geo3['Village_Tract'] = village_geo3.Village_Tract.str.replace(" ", "")
village_geo3['District'] = village_geo3.District.str.replace(" ","")

# %%
VT_ward_df['district'] = VT_ward_df['district'].apply(lambda x: 'Myitkyina District' if 'Myitkyinar' in x else x)
VT_ward_df['township'] = VT_ward_df['township'].apply(lambda x: 'Myitkyina Township' if 'Myitkyinar' in x else x)

# %%
VT_ward_df['district'] = VT_ward_df['district'].apply(lambda x: 'Yangon(North)District' if 'NorthDistrict' in x else x)
VT_ward_df['district'] = VT_ward_df['district'].apply(lambda x: 'Yangon(East)District' if 'EastDistrict' in x else x)
VT_ward_df['district'] = VT_ward_df['district'].apply(lambda x: 'Yangon(South)District' if 'SouthDistrict' in x else x)

# %%
VT_ward_df.head(2)
# Out:
#   Ward/VillageTract  tot_pop  male_pop  female_pop         state  \
# 0        Aye Yar(W)   3647.0    1694.0      1953.0  Kachin State
# 1        Thi Dar(W)   4143.0    2094.0      2049.0  Kachin State
#
#              district            township
# 0  Myitkyina District  Myitkyina Township
# 1  Myitkyina District  Myitkyina Township

# %%
wards_geo_df2.head(2)
# Out:
#              Township            District    Town_Pcode  Longitude   Latitude  \
# 0  Myitkyina Township  Myitkyina District  MMR001001701  97.390355  25.387488
# 1  Myitkyina Township  Myitkyina District  MMR001001701  97.390355  25.387488
#
#         Ward_Pcode        Ward
# 0  MMR001001701501  Aye Yar(W)
# 1  MMR001001701502  Thi Dar(W)

# %%
village_geo3.head(2)
# Out:
#        VT_Pcode   Village_Tract            District            Township  \
# 0  MMR001001001        Alam(VT)  Myitkyina District  Myitkyina Township
# 1  MMR001001002  Nawng Nang(VT)  Myitkyina District  Myitkyina Township
#
#    Longitude   Latitude
# 0  97.494898  25.577230
# 1  97.454205  25.490713

# %%
village_geo3.shape[0]
# Out:
# 13974

# %%
village_geo3[['Longitude', 'Latitude']].notnull().sum()
# Out:
# Longitude    13119
# Latitude     13119
# dtype: int64

# %%
print(wards_geo_df2.shape[0])
print(wards_geo_df2[['Longitude', 'Latitude']].notnull().sum())
# Out:
# 3170
# Longitude    3170
# Latitude     3170
# dtype: int64

# %%
VT_ward_df['Ward/VillageTract'].unique()
# Out:
# array(['Aye Yar(W)', 'Thi Dar(W)', 'Yan Gyi Aung(W)', ...,
#        'Du Yin Pin Shaung(VT)', 'Hka Lone(VT)', 'Ta Ron(VT)'], dtype=object)

# %%
village_geo3.District.unique()
# Out:
# array(['MyitkyinaDistrict', 'MohnyinDistrict', 'BhamoDistrict',
#        'Puta-ODistrict', 'LoikawDistrict', 'BawlakeDistrict',
#        'Hpa-AnDistrict', 'HpapunDistrict', 'MyawaddyDistrict',
#        'KawkareikDistrict', 'FalamDistrict', 'HakhaDistrict',
#        'MindatDistrict', 'SagaingDistrict', 'ShweboDistrict',
#        'KanbaluDistrict', 'MonywaDistrict', 'YinmarbinDistrict',
#        'KathaDistrict', 'KaleDistrict', 'TamuDistrict', 'MawlaikDistrict',
#        'HkamtiDistrict', 'DaweiDistrict', 'MyeikDistrict',
#        'KawthoungDistrict', 'BagoDistrict', 'TaungooDistrict',
#        'PyayDistrict', 'ThayarwadyDistrict', 'MagwayDistrict',
#        'MinbuDistrict', 'ThayetDistrict', 'PakokkuDistrict',
#        'GangawDistrict', 'MandalayDistrict', 'PyinoolwinDistrict',
#        'KyaukseDistrict', 'MyingyanDistrict', 'Nyaung-UDistrict',
#        'YamethinDistrict', 'NayPyiTawDistrict', 'MeiktilaDistrict',
#        'MawlamyineDistrict', 'ThatonDistrict', 'SittweDistrict',
#        'Mrauk-UDistrict', 'MaungdawDistrict', 'KyaukpyuDistrict',
#        'ThandweDistrict', 'Yangon(North)District', 'Yangon(East)District',
#        'Yangon(South)District', 'TaunggyiDistrict', 'LoilenDistrict',
#        'LangkhoDistrict', 'LashioDistrict', 'MatmanDistrict',
#        'HopangDistrict', 'MuseDistrict', 'KyaukmeDistrict',
#        'MongmitDistrict', 'LaukkaingDistrict',
#        'Laukkaing(KokangSAZ)District', 'MongMaw(WaSAD)District',
#        'WeinKawng(WeinKao)(WaSAD)District', 'KengtungDistrict',
#        'MonghsatDistrict', 'TachileikDistrict', 'MongPawk(WaSAD)District',
#        'PatheinDistrict', 'HinthadaDistrict', 'MyaungmyaDistrict',
#        'LabuttaDistrict', 'MaubinDistrict', 'PyaponDistrict',
#        'OkeTaRaDistrict', 'DetKhiNaDistrict'], dtype=object)

# %%
VT_ward_df.district.unique()
# Out:
# array(['MyitkyinaDistrict', 'MyeikDistrict', 'KawthoungDistrict',
#        'BagoDistrict', 'ToungooDistrict', 'MohnyinDistrict',
#        'PyayDistrict', 'ThayawadyDistrict', 'MagwayDistrict',
#        'MinbuDistrict', 'ThayetDistrict', 'PakokkuDistrict',
#        'GangawDistrict', 'ManadalayDistrict', 'MawlamyineDistrict',
#        'ThatonDistrict', 'BhamoDistrict', 'SittwayDistrict',
#        'MaukUDistrict', 'MaungtawDistrict', 'KyaukpyuDistrict',
#        'ThandweDistrict', 'NorthDistrict', 'EastDistrict', 'SouthDistrict',
#        'WestDistrict', 'PatheinDistrict', 'PutaoDistrict',
#        'PhyaponDistrict', 'MaubinDistrict', 'MyaungmyaDistrict',
#        'LabuttaDistrict', 'HinthadaDistrict', 'OttaraDistrict',
#        'DekkhinaDistrict', 'LoikawDistrict', 'BawlakheDistrict',
#        'HakaDistrict', 'FalamDistrict', 'MindatDistrict',
#        'SagaingDistrict', 'ShweboDistrict', 'MonywaDistrict',
#        'KathaDistrict', 'KalayDistrict', 'TamuDistrict', 'MawlaikDistrict',
#        'HkamtiDistrict', 'YinmarpinDistrict', 'DaweiDistrict'], dtype=object)

# %%
geo_df1 = pd.merge(VT_ward_df, wards_geo_df2, left_on =['Ward/VillageTract', 'district'], 
                                              right_on = ['Ward', 'District'])

# %%
geo_df2 = pd.merge(VT_ward_df, village_geo3, left_on =['Ward/VillageTract', 'district'], 
                                              right_on = ['Village_Tract', 'District'])

# %%
geo_df1.columns
# Out:
# Index(['Ward/VillageTract', 'tot_pop', 'male_pop', 'female_pop', 'state',
#        'district', 'township', 'Township', 'District', 'Town_Pcode',
#        'Longitude', 'Latitude', 'Ward_Pcode', 'Ward'],
#       dtype='object')

# %%
geo_df2.columns
# Out:
# Index(['Ward/VillageTract', 'tot_pop', 'male_pop', 'female_pop', 'state',
#        'district', 'township', 'VT_Pcode', 'Village_Tract', 'District',
#        'Township', 'Longitude', 'Latitude'],
#       dtype='object')

# %%
geo_df1 = geo_df1.loc[:,['Ward/VillageTract',  'tot_pop', 'male_pop', 'female_pop',  'Township','Longitude', 'Latitude']]
geo_df2 = geo_df2.loc[:,['Ward/VillageTract', 'tot_pop', 'male_pop', 'female_pop', 'Township','Longitude', 'Latitude']]

# %%
geo_df_total = pd.concat([geo_df1, geo_df2])

# %%
geo_df_total[['Longitude', 'Latitude']].notnull().sum()
# Out:
# Longitude    10004
# Latitude     10004
# dtype: int64

# %%
geo_df_total.to_csv('VT_Ward_geo.csv')

# %%
geo_df['Long'] = geo_df[['Longitude_x', 'Longitude_y']].fillna(0).sum(axis=1)
geo_df['Lat'] = geo_df[['Latitude_x', 'Latitude_y']].fillna(0).sum(axis=1)

# %%
geo_df['Long'] = geo_df['Long'].replace(0, np.nan)
geo_df['Lat'] = geo_df['Lat'].replace(0, np.nan)

# %%
geo_df.shape[0]
# Out:
# 12142

# %%
geo_df['Long'].notnull().sum()
# Out:
# 509

# %%
geo_df[['Long', 'Lat']].dropna().shape
# Out:
# (509, 2)

# %%
geo_df[['Ward/VillageTract', 'tot_pop', 'male_pop', 'female_pop', 'Long', 'Lat']].to_csv('VT_Ward.csv')

# %%
final_geodf = geo_df[['Ward/VillageTract', 'tot_pop', 'male_pop', 'female_pop', 'Long', 'Lat']]

# %%
pickle.dump(geo_df, open( "geo_df.p", "wb" ))
